# %%
import pandas as pd

data = {'Nomi': ['Alice', ' Bob', 'Gian Franco', 'David'],
        'Nomi_Cognomi': ['Alice Blues', ' Bob Cartney', 'GianFranco Porri', 'David Lee'],
        'Anni': [24,56,29,37]
        }

df = pd.DataFrame(data)
df
# Out:
#           Nomi      Nomi_Cognomi  Anni
# 0        Alice       Alice Blues    24
# 1          Bob       Bob Cartney    56
# 2  Gian Franco  GianFranco Porri    29
# 3        David         David Lee    37

# %%
#Aggiungi una nuova colonna (Lunghezza) al tuo DataFrame che contenga la lunghezza di ogni stringa in un'altra colonna

# %%
# Out:
#           Nomi      Nomi_Cognomi  Anni  Lunghezza
# 0        Alice       Alice Blues    24          5
# 1          Bob       Bob Cartney    56          4
# 2  Gian Franco  GianFranco Porri    29         11
# 3        David         David Lee    37          5

# %%
#Modifica tutte le stringhe in una colonna in maiuscolo(Nomi_Maiuscolo).

# %%
# Out:
#           Nomi      Nomi_Cognomi  Anni  Lunghezza Nomi_Maiuscolo
# 0        Alice       Alice Blues    24          5          ALICE
# 1          Bob       Bob Cartney    56          4            BOB
# 2  Gian Franco  GianFranco Porri    29         11    GIAN FRANCO
# 3        David         David Lee    37          5          DAVID

# %%
#Conta quante volte una particolare sottostringa appare in una colonna.(Conta_A)

# %%
# Out:
#           Nomi      Nomi_Cognomi  Anni  Lunghezza Nomi_Maiuscolo  Conta_A
# 0        Alice       Alice Blues    24          5          ALICE        0
# 1          Bob       Bob Cartney    56          4            BOB        0
# 2  Gian Franco  GianFranco Porri    29         11    GIAN FRANCO        2
# 3        David         David Lee    37          5          DAVID        1

# %%
#Estrai i primi tre caratteri da ogni stringa in una colonna(Primi_3_Caratteri)

# %%
# Out:
#           Nomi      Nomi_Cognomi  Anni  Lunghezza Nomi_Maiuscolo  Conta_A  \
# 0        Alice       Alice Blues    24          5          ALICE        0
# 1          Bob       Bob Cartney    56          4            BOB        0
# 2  Gian Franco  GianFranco Porri    29         11    GIAN FRANCO        2
# 3        David         David Lee    37          5          DAVID        1
#
#   Primi_3_Caratteri
# 0               Ali
# 1                Bo
# 2               Gia
# 3               Dav

# %%
#Estrai gli ultimi 2 caratteri da ogni stringa in una colonna(Ultimi_2_Caratteri)

# %%
# Out:
#           Nomi      Nomi_Cognomi  Anni  Lunghezza Nomi_Maiuscolo  Conta_A  \
# 0        Alice       Alice Blues    24          5          ALICE        0
# 1          Bob       Bob Cartney    56          4            BOB        0
# 2  Gian Franco  GianFranco Porri    29         11    GIAN FRANCO        2
# 3        David         David Lee    37          5          DAVID        1
#
#   Primi_3_Caratteri Ultimi_2_Caratteri
# 0               Ali                 ce
# 1                Bo                 ob
# 2               Gia                 co
# 3               Dav                 id

# %%
#Sostituisci una particolare sottostringa con un'altra in una colonna.(Nomi_Modificati)

# %%
# Out:
#           Nomi      Nomi_Cognomi  Anni  Lunghezza Nomi_Maiuscolo  Conta_A  \
# 0        Alice       Alice Blues    24          5          ALICE        0
# 1          Bob       Bob Cartney    56          4            BOB        0
# 2  Gian Franco  GianFranco Porri    29         11    GIAN FRANCO        2
# 3        David         David Lee    37          5          DAVID        1
#
#   Primi_3_Caratteri Ultimi_2_Caratteri Nomi_Modificati
# 0               Ali                 ce           Alice
# 1                Bo                 ob             Bob
# 2               Gia                 co     GiXn FrXnco
# 3               Dav                 id           DXvid

# %%
#Aggiungi una colonna booleana (Contiene_C) che indica se una certa sottostringa è presente in ogni stringa.

# %%
# Out:
#           Nomi      Nomi_Cognomi  Anni  Lunghezza Nomi_Maiuscolo  Conta_A  \
# 0        Alice       Alice Blues    24          5          ALICE        0
# 1          Bob       Bob Cartney    56          4            BOB        0
# 2  Gian Franco  GianFranco Porri    29         11    GIAN FRANCO        2
# 3        David         David Lee    37          5          DAVID        1
#
#   Primi_3_Caratteri Ultimi_2_Caratteri Nomi_Modificati  Contiene_C
# 0               Ali                 ce           Alice        True
# 1                Bo                 ob             Bob       False
# 2               Gia                 co     GiXn FrXnco        True
# 3               Dav                 id           DXvid       False

# %%
#Suddividi una colonna di stringhe in base a un delimitatore e crea nuove colonne.

# %%
# Out:
#           Nomi      Nomi_Cognomi  Anni  Lunghezza Nomi_Maiuscolo  Conta_A  \
# 0        Alice       Alice Blues    24          5          ALICE        0
# 1          Bob       Bob Cartney    56          4            BOB        0
# 2  Gian Franco  GianFranco Porri    29         11    GIAN FRANCO        2
# 3        David         David Lee    37          5          DAVID        1
#
#   Primi_3_Caratteri Ultimi_2_Caratteri Nomi_Modificati  Contiene_C  \
# 0               Ali                 ce           Alice        True
# 1                Bo                 ob             Bob       False
# 2               Gia                 co     GiXn FrXnco        True
# 3               Dav                 id           DXvid       False
#
#    Primo_Nome  Cognome
# 0       Alice    Blues
# 1         Bob  Cartney
# 2  GianFranco    Porri
# 3       David      Lee

# %%
#Elimina gli spazi bianchi all'inizio e alla fine di ogni stringa in una colonna (Nomi_Senza_Spazi)

# %%
# Out:
#           Nomi      Nomi_Cognomi  Anni  Lunghezza Nomi_Maiuscolo  Conta_A  \
# 0        Alice       Alice Blues    24          5          ALICE        0
# 1          Bob       Bob Cartney    56          4            BOB        0
# 2  Gian Franco  GianFranco Porri    29         11    GIAN FRANCO        2
# 3        David         David Lee    37          5          DAVID        1
#
#   Primi_3_Caratteri Ultimi_2_Caratteri Nomi_Modificati  Contiene_C  \
# 0               Ali                 ce           Alice        True
# 1                Bo                 ob             Bob       False
# 2               Gia                 co     GiXn FrXnco        True
# 3               Dav                 id           DXvid       False
#
#    Primo_Nome  Cognome Nomi_Senza_Spazi
# 0       Alice    Blues            Alice
# 1         Bob  Cartney              Bob
# 2  GianFranco    Porri      Gian Franco
# 3       David      Lee            David

# %%
#Conta il numero di parole in ogni stringa di una colonna.(Conta_Parole)

# %%
# Out:
#           Nomi      Nomi_Cognomi  Anni  Lunghezza Nomi_Maiuscolo  Conta_A  \
# 0        Alice       Alice Blues    24          5          ALICE        0
# 1          Bob       Bob Cartney    56          4            BOB        0
# 2  Gian Franco  GianFranco Porri    29         11    GIAN FRANCO        2
# 3        David         David Lee    37          5          DAVID        1
#
#   Primi_3_Caratteri Ultimi_2_Caratteri Nomi_Modificati  Contiene_C  \
# 0               Ali                 ce           Alice        True
# 1                Bo                 ob             Bob       False
# 2               Gia                 co     GiXn FrXnco        True
# 3               Dav                 id           DXvid       False
#
#    Primo_Nome  Cognome Nomi_Senza_Spazi  Conta_Parole
# 0       Alice    Blues            Alice             1
# 1         Bob  Cartney              Bob             1
# 2  GianFranco    Porri      Gian Franco             2
# 3       David      Lee            David             1

# %%
#Combina più colonne di stringhe in una colonna formattata.

# %%
# Out:
#           Nomi      Nomi_Cognomi  Anni  Lunghezza Nomi_Maiuscolo  Conta_A  \
# 0        Alice       Alice Blues    24          5          ALICE        0
# 1          Bob       Bob Cartney    56          4            BOB        0
# 2  Gian Franco  GianFranco Porri    29         11    GIAN FRANCO        2
# 3        David         David Lee    37          5          DAVID        1
#
#   Primi_3_Caratteri Ultimi_2_Caratteri Nomi_Modificati  Contiene_C  \
# 0               Ali                 ce           Alice        True
# 1                Bo                 ob             Bob       False
# 2               Gia                 co     GiXn FrXnco        True
# 3               Dav                 id           DXvid       False
#
#    Primo_Nome  Cognome Nomi_Senza_Spazi  Conta_Parole     Nome_Completo
# 0       Alice    Blues            Alice             1       Alice Blues
# 1         Bob  Cartney              Bob             1       Bob Cartney
# 2  GianFranco    Porri      Gian Franco             2  GianFranco Porri
# 3       David      Lee            David             1         David Lee
