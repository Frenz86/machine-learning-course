# %% [markdown]
# ## Classi made easy

# %%
class Triangolo:

    def area(self,b,h):
        ar = b*h/2
        return ar
    def perimetro(self,a,b,c):
        per = a+b+c
        return per

# %%
trian =  Triangolo()

# %%
trian.area(5,4)
# Out:
# 10.0

# %%
trian.perimetro(6,5,4)
# Out:
# 15

# %%
#però ogni volta dobbiamo passsare di volta in volta i parametri dei metodi,
#concettualmente è sbagliato

# %%
class Triangolo:

    """
    questa classe rappresenta il triangolo
    """
    def __init__(self,a,b,c,h):
        self.a = a
        self.b = b
        self.c = c
        self.h = h

    def area(self):
        """
        Calcolo area
        """
        ar = self.b*self.h
        return ar

    def perimetro(self):
        """
        Calcolo perimetro
        """
        per = self.a+self.b+self.c
        return per

    def print_info(self):
        print("Area del triangolo = %2.f"% self.area())
        print("Perimentro del triangolo = %2.f"% self.perimetro())

# %%
help(Triangolo)
# Out:
# Help on class Triangolo in module __main__:
#
# class Triangolo(builtins.object)
#  |  Triangolo(a, b, c, h)
#  |
#  |  questa classe rappresenta il triangolo
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, a, b, c, h)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  area(self)
#  |      Calcolo area
#  |
#  |  perimetro(self)
#  |      Calcolo perimetro
#  |
#  |  print_info(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
trian =  Triangolo(6,5,4,4)

# %%
trian.area()
# Out:
# 20

# %%
trian.perimetro()
# Out:
# 15

# %%
trian.print_info()
# Out:
# Area del triangolo = 20
# Perimentro del triangolo = 15
