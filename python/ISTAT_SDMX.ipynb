# %% [markdown]
# ## ISTAT API
# Introduzione all'utilizzo delle API Istat by @Daniele Grotti
#
# <img src="https://frenzy86.s3.eu-west-2.amazonaws.com/python/istat.png" width=1200 >

# %% [markdown]
# ## SDMX
# https://www.istat.it/it/metodi-e-strumenti/web-service-sdmx
#
# SDMX(Statistical Data and Metadata eXchange) sviluppato da sette organizzazioni internazionali (Bank for International Settlements, European Central Bank, Eurostat, International Monetary Fund, Organisation for Economic Cooperation and Development (OECD), United Nations Statistical Division, World Bank) per facilitare lo scambio e la condivisione di dati e metadati statistici.
#
# Dal 2013 SDMX è diventato uno standard ISO (IS 17369).
#
# SDMX è anche alla base del progetto Hub della statistica pubblica per la condivisione, l'integrazione e la diffusione di macrodati prodotti dai soggetti del Sistema Statistico Nazionale (Sistan) o da altri enti produttori di statistiche che svolgono funzioni o servizi d'interesse pubblico. SDMX si basa su un solido modello informativo adottato anche dal W3C per la descrizione dei dati multidimensionali in ambito Linked Open Data attraverso l'RDF Data Cube Vocabolary.

# %% [markdown]
# ## SEP
# Il Single Exit Point (SEP) è una API esposta dall'Istituto Nazionale di Statistica (Istat) per permettere l'accesso in modalità machine-to-machine ai dati memorizzati nel database di diffusione I.Stat. Il servizio, gratuito e liberamente disponibile, consente agli enti e alle organizzazioni di formulare specifiche richieste (query), di effettuare il download dei dati di interesse e di accoglierli agevolmente nei propri sistemi (basi dati, portali web ecc.). La ricerca delle statistiche correntemente prodotte dall’Istat è facilitata da una catalogazione per temi.
# https://developers.italia.it/it/api/istat-sdmx-rest

# %%
# !pip install istatapi -q

# %%
from istatapi import discovery, retrieval
import matplotlib.pyplot as plt
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

discovery.all_available()
# Out:
#         df_id version                                     df_description  \
# 0    101_1015     1.3                                              Crops
# 1    101_1030     1.0                  PDO, PGI and TSG quality products
# 2    101_1033     1.0                                       slaughtering
# 3    101_1039     1.2                       Agritourism - municipalities
# 4    101_1077     1.0  PDO, PGI and TSG products:  operators - munici...
# ..        ...     ...                                                ...
# 504    97_953     1.1               Environmental protection expenditure
# 505   98_1066     1.0  Productivity measures - Accounts in the 2014 v...
# 506   98_1067     1.0  Productivity measures - Accounts in the 2011 v...
# 507    98_197     1.3                              Productivity measures
# 508     9_951     1.3                               Mining and quarrying
#
#            df_structure_id
# 0        DCSP_COLTIVAZIONI
# 1              DCSP_DOPIGP
# 2        DCSP_MACELLAZIONI
# 3     DCSP_AGRITURISMO_COM
# 4          DCSP_DOPIGP_COM
# ..                     ...
# 504      DCCN_SPESAPROTAMB
# 505  DCCN_PRODUTTIVITA_B14
# 506  DCCN_PRODUTTIVITA_B11
# 507      DCCN_PRODUTTIVITA
# 508          DCCV_CAVE_MIN
#
# [509 rows x 4 columns]

# %%
## RICERCA BY KEYWORD UNEMPLOYMENT
discovery.search_dataset("unempl")
# Out:
#         df_id version                                     df_description  \
# 93   151_1176     1.0  Unemployment rate  - monthly data - previous r...
# 94   151_1177     1.0  Unemployed  - monthly data - previous regulati...
# 95   151_1178     1.0  Unemployment rate - quarterly seasonally adjus...
# 96   151_1179     1.0  Unemployed - quarterly seasonally adjusted dat...
# 97   151_1192     1.0    Unemployment - previous regulation (until 2020)
# 98   151_1193     1.0  Unemployment  rate - previous regulation (unti...
# 99    151_874     1.2                  Unemployment rate  - monthly data
# 100   151_877     1.5                         Unemployed  - monthly data
# 101   151_884     1.2  Unemployment rate - quarterly seasonally adjus...
# 102   151_885     1.1    Unemployed - quarterly seasonally adjusted data
# 103   151_914     1.2                                 Unemployment  rate
# 104   151_929     1.2                                       Unemployment
# 182  172_1197     1.0  Supplementary  indicators to unemployment - pr...
# 184   172_926     1.1          Supplementary  indicators to unemployment
#
#                   df_structure_id
# 93   DCCV_TAXDISOCCUMENS1_UNT2020
# 94    DCCV_DISOCCUPTMENS1_UNT2020
# 95     DCCV_TAXDISOCCUDE1_UNT2020
# 96      DCCV_DISOCCUPTDE1_UNT2020
# 97        DCCV_DISOCCUPT1_UNT2020
# 98       DCCV_TAXDISOCCU1_UNT2020
# 99           DCCV_TAXDISOCCUMENS1
# 100           DCCV_DISOCCUPTMENS1
# 101            DCCV_TAXDISOCCUDE1
# 102             DCCV_DISOCCUPTDE1
# 103              DCCV_TAXDISOCCU1
# 104               DCCV_DISOCCUPT1
# 182           DCCV_COMPL1_UNT2020
# 184                   DCCV_COMPL1

# %%
## RICERCA BY KEYWORD POP
discovery.search_dataset("pop")
# Out:
#         df_id version                                     df_description  \
# 106  152_1181     1.0  Inactive population  - monthly data- previous ...
# 108  152_1183     1.0  Inactive population - quarterly seasonally adj...
# 109  152_1185     1.0  Inactive  population - previous regulation (un...
# 112   152_879     1.2                Inactive population  - monthly data
# 114   152_887     1.3  Inactive population - quarterly seasonally adj...
# 116   152_928     1.2                               Inactive  population
# 158   164_164     1.1    Estimated resident population - Years 2002-2019
# 207   22_1201     1.1  Semi-supercentenarian population (105 years an...
# 208    22_289     1.5                Resident population  on 1st January
# 210    22_315     2.1                     Resident population  - balance
# 249   283_138     1.0  New series of estimates on the resident popula...
# 346   52_1194     1.0  Population 15 years and over by highest level ...
# 349    52_912     1.0  Population 15 years and over by highest level ...
# 350  532_1195     1.0  Popoulation  by labour status - previous regul...
# 351   532_930     1.1                      Popoulation  by labour status
# 425  730_1049     1.1  Regular, irregular employment and population -...
# 438  737_1087     1.1  Regular, irregular employment and population -...
# 443    73_173     1.2  Prison population held in institutions for adu...
#
#                df_structure_id
# 106  DCCV_INATTIVMENS1_UNT2020
# 108    DCCV_INATTIVDE1_UNT2020
# 109      DCCV_INATTIV1_UNT2020
# 112          DCCV_INATTIVMENS1
# 114            DCCV_INATTIVDE1
# 116              DCCV_INATTIV1
# 158         DCIS_RICPOPRES2011
# 207                DCIS_SSCENT
# 208               DCIS_POPRES1
# 210           DCIS_POPORESBIL1
# 249               DCIS_RICSTAT
# 346       DCCV_POPTIT1_UNT2020
# 349               DCCV_POPTIT1
# 350      DCCV_POPCOND1_UNT2020
# 351              DCCV_POPCOND1
# 425       DCCN_OCCNSEC2010_B14
# 438       DCCN_OCCTSEC2010_B14
# 443              DCCV_DETENUTI

# %%
## RICERCA DEI DATASET BY ID NUMBER:
## 22_289 --> Resident population on 1st January
ds = discovery.DataSet(dataflow_identifier="22_289")
# VARIABILI DEL DATASET
ds.dimensions_info()
# Out:
#      dimension    dimension_ID     description
# 0         FREQ         CL_FREQ       Frequency
# 1          ETA         CL_ETA1       Age class
# 2     ITTER107     CL_ITTER107       Territory
# 3        SESSO    CL_SEXISTAT1          Gender
# 4      STACIVX     CL_STATCIV2  Marital status
# 5  TIPO_INDDEM  CL_TIPO_DATO15    Data type 15

# %%
dimension = "SESSO" #CODICE SESSO
ds.get_dimension_values(dimension)
# Out:
#   values_ids values_description
# 0          1              males
# 1          9              total
# 2          2            females

# %%
dimension = "ITTER107" #ISTAT Code comune
ds.get_dimension_values(dimension)
# Out:
#      values_ids    values_description
# 0            IT                 Italy
# 1           ITG                 Isole
# 2          ITFG           Mezzogiorno
# 3           ITF                   Sud
# 4          ITF2                Molise
# ...         ...                   ...
# 8501     062029              Faicchio
# 8502     064082  San Mango sul Calore
# 8503     063039               Lettere
# 8504     108007           Bernareggio
# 8505     055003               Alviano
#
# [8506 rows x 2 columns]

# %%
dimension = "TIPO_INDDEM" #use "dimension" column from above
ds.get_dimension_values(dimension)
# Out:
#   values_ids         values_description
# 0        JAN  population on 1st January

# %%
dimension = "STACIVX" #Marital status
ds.get_dimension_values(dimension)
# Out:
#   values_ids                       values_description
# 0         17          divorced same-sex civil partner
# 1          1                            never married
# 2         16  widow/widower of same-sex civil partner
# 3         99                                    total
# 4         15                   same sex civil partner
# 5          3                                 divorced
# 6          2                                  married
# 7          4                                  widowed

# %%
dimension = "ITTER107" #ISTAT cde 107
ds.get_dimension_values(dimension)
# Out:
#      values_ids    values_description
# 0            IT                 Italy
# 1           ITG                 Isole
# 2          ITFG           Mezzogiorno
# 3           ITF                   Sud
# 4          ITF2                Molise
# ...         ...                   ...
# 8501     062029              Faicchio
# 8502     064082  San Mango sul Calore
# 8503     063039               Lettere
# 8504     108007           Bernareggio
# 8505     055003               Alviano
#
# [8506 rows x 2 columns]

# %%
## NON SPECIFICANDO ETA, il dataset ha una granularità per fascia di età annuale (da zero a 99, oppure TOTAL)
TIPO_INDDEM = ["JAN"] #
ISTATCOMUNE = "055003"

ds.set_filters(tipo_dato = TIPO_INDDEM,ITTER107=ISTATCOMUNE)
df = retrieval.get_data(ds)
df
# Out:
#              DATAFLOW FREQ    ETA  ITTER107  SESSO  STACIVX TIPO_INDDEM  \
# 0     IT1:22_289(1.5)    A  TOTAL     55003      1        1         JAN
# 6924  IT1:22_289(1.5)    A    Y80     55003      2        4         JAN
# 2726  IT1:22_289(1.5)    A    Y39     55003      2        3         JAN
# 2730  IT1:22_289(1.5)    A    Y39     55003      2        4         JAN
# 6920  IT1:22_289(1.5)    A    Y80     55003      2        3         JAN
# ...               ...  ...    ...       ...    ...      ...         ...
# 2831  IT1:22_289(1.5)    A    Y40     55003      1       99         JAN
# 6839  IT1:22_289(1.5)    A    Y79     55003      9       99         JAN
# 4343  IT1:22_289(1.5)    A    Y55     55003      1       99         JAN
# 4475  IT1:22_289(1.5)    A    Y56     55003      2       99         JAN
# 8873  IT1:22_289(1.5)    A    Y99     55003      9       99         JAN
#
#      TIME_PERIOD  OBS_VALUE  BREAK  CONF_STATUS  OBS_PRE_BREAK OBS_STATUS  \
# 0     2019-01-01      279.0    NaN          NaN            NaN        NaN
# 6924  2019-01-01       11.0    NaN          NaN            NaN        NaN
# 2726  2019-01-01        0.0    NaN          NaN            NaN        NaN
# 2730  2019-01-01        0.0    NaN          NaN            NaN        NaN
# 6920  2019-01-01        0.0    NaN          NaN            NaN        NaN
# ...          ...        ...    ...          ...            ...        ...
# 2831  2023-01-01        6.0    NaN          NaN            NaN          e
# 6839  2023-01-01       15.0    NaN          NaN            NaN          e
# 4343  2023-01-01       12.0    NaN          NaN            NaN          e
# 4475  2023-01-01       18.0    NaN          NaN            NaN          e
# 8873  2023-01-01        0.0    NaN          NaN            NaN          e
#
#       BASE_PER  UNIT_MEAS  UNIT_MULT  METADATA_EN  METADATA_IT
# 0          NaN        NaN        NaN          NaN          NaN
# 6924       NaN        NaN        NaN          NaN          NaN
# 2726       NaN        NaN        NaN          NaN          NaN
# 2730       NaN        NaN        NaN          NaN          NaN
# 6920       NaN        NaN        NaN          NaN          NaN
# ...        ...        ...        ...          ...          ...
# 2831       NaN        NaN        NaN          NaN          NaN
# 6839       NaN        NaN        NaN          NaN          NaN
# 4343       NaN        NaN        NaN          NaN          NaN
# 4475       NaN        NaN        NaN          NaN          NaN
# 8873       NaN        NaN        NaN          NaN          NaN
#
# [8874 rows x 18 columns]

# %%
freq = "A" #ANNUAL frequency
TIPO_INDDEM = ["JAN"] #
ISTATCOMUNE = "055003" #Alviano
ETA = 'TOTAL'
SESSO = ["1","2"] #MASCHIO FEMMINA
STACIVX = "99" # TOTAL NO DIVIDED BY MARRIAGE
TIME_PERIOD = "2023-01-01"

ds.set_filters(freq = freq, tipo_dato = TIPO_INDDEM,ITTER107=ISTATCOMUNE,ETA=ETA,SESSO=SESSO,STACIVX=STACIVX,)
df = retrieval.get_data(ds)
df = df[df['TIME_PERIOD'] >= TIME_PERIOD]
df
# Out:
#           DATAFLOW FREQ    ETA  ITTER107  SESSO  STACIVX TIPO_INDDEM  \
# 4  IT1:22_289(1.5)    A  TOTAL     55003      1       99         JAN
# 9  IT1:22_289(1.5)    A  TOTAL     55003      2       99         JAN
#
#   TIME_PERIOD  OBS_VALUE  BREAK  CONF_STATUS  OBS_PRE_BREAK OBS_STATUS  \
# 4  2023-01-01        655    NaN          NaN            NaN          e
# 9  2023-01-01        710    NaN          NaN            NaN          e
#
#    BASE_PER  UNIT_MEAS  UNIT_MULT  METADATA_EN  METADATA_IT
# 4       NaN        NaN        NaN          NaN          NaN
# 9       NaN        NaN        NaN          NaN          NaN

# %%
df['SESSO'].value_counts(normalize=True)
# Out:
# 1    0.5
# 2    0.5
# Name: SESSO, dtype: float64

# %%
## MOLISE AGGREGATO
freq = "A" #ANNUAL frequency
TIPO_INDDEM = ["JAN"] #
ISTATCOMUNE = "ITF2" #Molise
ETA = 'TOTAL'
SESSO = ["1","2"] #MASCHIO FEMMINA
STACIVX = "99" # TOTAL NO DIVIDED BY MARRIAGE
TIME_PERIOD = "2023-01-01"

ds.set_filters(freq = freq, tipo_dato = TIPO_INDDEM,ITTER107=ISTATCOMUNE,ETA=ETA,SESSO=SESSO,STACIVX=STACIVX,)
df = retrieval.get_data(ds)
df = df[df['TIME_PERIOD'] >= TIME_PERIOD]
df
# Out:
#           DATAFLOW FREQ    ETA ITTER107  SESSO  STACIVX TIPO_INDDEM  \
# 4  IT1:22_289(1.5)    A  TOTAL     ITF2      1       99         JAN
# 9  IT1:22_289(1.5)    A  TOTAL     ITF2      2       99         JAN
#
#   TIME_PERIOD  OBS_VALUE  BREAK  CONF_STATUS  OBS_PRE_BREAK OBS_STATUS  \
# 4  2023-01-01     143080    NaN          NaN            NaN          e
# 9  2023-01-01     146760    NaN          NaN            NaN          e
#
#    BASE_PER  UNIT_MEAS  UNIT_MULT  METADATA_EN  METADATA_IT
# 4       NaN        NaN        NaN          NaN          NaN
# 9       NaN        NaN        NaN          NaN          NaN

# %% [markdown]
# ## DISOCCUPAZIONE

# %%
## RICERCA BY KEYWORD UNEMPLOYMENT
discovery.search_dataset("unempl")
# Out:
#         df_id version                                     df_description  \
# 93   151_1176     1.0  Unemployment rate  - monthly data - previous r...
# 94   151_1177     1.0  Unemployed  - monthly data - previous regulati...
# 95   151_1178     1.0  Unemployment rate - quarterly seasonally adjus...
# 96   151_1179     1.0  Unemployed - quarterly seasonally adjusted dat...
# 97   151_1192     1.0    Unemployment - previous regulation (until 2020)
# 98   151_1193     1.0  Unemployment  rate - previous regulation (unti...
# 99    151_874     1.2                  Unemployment rate  - monthly data
# 100   151_877     1.5                         Unemployed  - monthly data
# 101   151_884     1.2  Unemployment rate - quarterly seasonally adjus...
# 102   151_885     1.1    Unemployed - quarterly seasonally adjusted data
# 103   151_914     1.2                                 Unemployment  rate
# 104   151_929     1.2                                       Unemployment
# 182  172_1197     1.0  Supplementary  indicators to unemployment - pr...
# 184   172_926     1.1          Supplementary  indicators to unemployment
#
#                   df_structure_id
# 93   DCCV_TAXDISOCCUMENS1_UNT2020
# 94    DCCV_DISOCCUPTMENS1_UNT2020
# 95     DCCV_TAXDISOCCUDE1_UNT2020
# 96      DCCV_DISOCCUPTDE1_UNT2020
# 97        DCCV_DISOCCUPT1_UNT2020
# 98       DCCV_TAXDISOCCU1_UNT2020
# 99           DCCV_TAXDISOCCUMENS1
# 100           DCCV_DISOCCUPTMENS1
# 101            DCCV_TAXDISOCCUDE1
# 102             DCCV_DISOCCUPTDE1
# 103              DCCV_TAXDISOCCU1
# 104               DCCV_DISOCCUPT1
# 182           DCCV_COMPL1_UNT2020
# 184                   DCCV_COMPL1

# %%
## RICERCA DEI DATASET BY ID NUMBER:
## 151_929 --> Unemployment	#LIVELLO PROVINCIALE
ds = discovery.DataSet(dataflow_identifier="151_929")

# VARIABILI DEL DATASET
ds.dimensions_info()
# Out:
#            dimension        dimension_ID         description
# 0               FREQ             CL_FREQ           Frequency
# 1       CITTADINANZA     CL_CITTADINANZA         Citizenship
# 2    CONDIZIONE_PROF  CL_CONDIZIONE_PROF       Labour status
# 3  DURATA_DISOCCUPAZ           CL_DURATA            Duration
# 4         CLASSE_ETA             CL_ETA1           Age class
# 5           ITTER107         CL_ITTER107           Territory
# 6              SESSO        CL_SEXISTAT1              Gender
# 7          TIPO_DATO    CL_TIPO_DATO_FOL       Data type FOL
# 8      TITOLO_STUDIO    CL_TITOLO_STUDIO  Level of education

# %%
dimension = "TIPO_DATO" #Data type FOL
ds.get_dimension_values(dimension)
# Out:
#   values_ids                                values_description
# 0      UNEMP  unemployed persons 15 years and more (thousands)

# %%
dimension = "ITTER107" #Data type FOL
ds.get_dimension_values(dimension)
# Out:
#     values_ids values_description
# 0           IT              Italy
# 1         ITFG        Mezzogiorno
# 2         ITF2             Molise
# 3          ITF                Sud
# 4         ITF4             Puglia
# ..         ...                ...
# 134      ITF34           Avellino
# 135      ITF31            Caserta
# 136      ITF35            Salerno
# 137      ITF33             Napoli
# 138      ITF32          Benevento
#
# [139 rows x 2 columns]

# %%
freq = "A" #ANNUAL frequency
ISTATCOMUNE = "ITD5"

ds.set_filters(freq = freq,ITTER107=ISTATCOMUNE)
df = retrieval.get_data(ds)
df
# Out:
#             DATAFLOW FREQ CITTADINANZA CONDIZIONE_PROF DURATA_DISOCCUPAZ  \
# 0   IT1:151_929(1.2)    A        TOTAL              2A             TOTAL
# 35  IT1:151_929(1.2)    A        TOTAL              2C             TOTAL
# 15  IT1:151_929(1.2)    A        TOTAL              2B             TOTAL
# 60  IT1:151_929(1.2)    A        TOTAL              99             TOTAL
# 50  IT1:151_929(1.2)    A        TOTAL              99             TOTAL
# ..               ...  ...          ...             ...               ...
# 49  IT1:151_929(1.2)    A        TOTAL              99             TOTAL
# 24  IT1:151_929(1.2)    A        TOTAL              2B             TOTAL
# 19  IT1:151_929(1.2)    A        TOTAL              2B             TOTAL
# 9   IT1:151_929(1.2)    A        TOTAL              2A             TOTAL
# 74  IT1:151_929(1.2)    A        TOTAL              99             TOTAL
#
#    CLASSE_ETA ITTER107  SESSO TIPO_DATO  TITOLO_STUDIO  ... OBS_VALUE  BREAK  \
# 0      Y15-74     ITD5      1     UNEMP             99  ...    35.778    NaN
# 35     Y15-74     ITD5      2     UNEMP             99  ...    12.137    NaN
# 15     Y15-74     ITD5      1     UNEMP             99  ...    10.754    NaN
# 60     Y15-74     ITD5      9     UNEMP             13  ...    53.958    NaN
# 50     Y15-74     ITD5      2     UNEMP             99  ...    69.924    NaN
# ..        ...      ...    ...       ...            ...  ...       ...    ...
# 49     Y15-74     ITD5      1     UNEMP             99  ...    46.430    NaN
# 24     Y15-74     ITD5      2     UNEMP             99  ...    15.321    NaN
# 19     Y15-74     ITD5      1     UNEMP             99  ...     8.095    NaN
# 9      Y15-74     ITD5      2     UNEMP             99  ...    32.528    NaN
# 74     Y15-74     ITD5      9     UNEMP             99  ...   105.299    NaN
#
#     CONF_STATUS  OBS_PRE_BREAK  OBS_STATUS  BASE_PER  UNIT_MEAS  UNIT_MULT  \
# 0           NaN            NaN         NaN       NaN        NaN        NaN
# 35          NaN            NaN         NaN       NaN        NaN        NaN
# 15          NaN            NaN         NaN       NaN        NaN        NaN
# 60          NaN            NaN         NaN       NaN        NaN        NaN
# 50          NaN            NaN         NaN       NaN        NaN        NaN
# ..          ...            ...         ...       ...        ...        ...
# 49          NaN            NaN         NaN       NaN        NaN        NaN
# 24          NaN            NaN         NaN       NaN        NaN        NaN
# 19          NaN            NaN         NaN       NaN        NaN        NaN
# 9           NaN            NaN         NaN       NaN        NaN        NaN
# 74          NaN            NaN         NaN       NaN        NaN        NaN
#
#     METADATA_EN  METADATA_IT
# 0           NaN          NaN
# 35          NaN          NaN
# 15          NaN          NaN
# 60          NaN          NaN
# 50          NaN          NaN
# ..          ...          ...
# 49          NaN          NaN
# 24          NaN          NaN
# 19          NaN          NaN
# 9           NaN          NaN
# 74          NaN          NaN
#
# [75 rows x 21 columns]

# %% [markdown]
# ## Download Geojson Comuni Italiani

# %%
# !git clone https://github.com/openpolis/geojson-italy
# Out:
# Cloning into 'geojson-italy'...
# remote: Enumerating objects: 2097, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 2097 (delta 12), reused 11 (delta 9), pack-reused 2073
# Receiving objects: 100% (2097/2097), 183.57 MiB | 10.29 MiB/s, done.
# Resolving deltas: 100% (1239/1239), done.
# Updating files: 100% (276/276), done.

# %%
import geopandas as gpd

file_path = "geojson-italy/comuni.geojson"
gdf = gpd.read_file(file_path)
gdf
# Out:
#                     name op_id name_de name_sl minint_elettorale  \
# 0                  Agliè   130    None    None        1010810010
# 1                Airasca   131    None    None        1010810020
# 2           Ala di Stura   132    None    None        1010810030
# 3        Albiano d'Ivrea   133    None    None        1010810040
# 4                 Almese   135    None    None        1010810060
# ...                  ...   ...     ...     ...               ...
# 7894  Presicce-Acquarica  None    None    None              None
# 7895     Borgo d'Anaunia  None    None    None              None
# 7896             Novella  None    None    None              None
# 7897     Ville di Fiemme  None    None    None              None
# 7898         Misiliscemi  None    None    None              None
#
#      minint_finloc name_it prov_name prov_istat_code  prov_istat_code_num  \
# 0       1010810010    None    Torino             001                    1
# 1       1010810020    None    Torino             001                    1
# 2       1010810030    None    Torino             001                    1
# 3       1010810040    None    Torino             001                    1
# 4       1010810060    None    Torino             001                    1
# ...            ...     ...       ...             ...                  ...
# 7894          None    None     Lecce             075                   75
# 7895          None    None    Trento             022                   22
# 7896          None    None    Trento             022                   22
# 7897          None    None    Trento             022                   22
# 7898          None    None   Trapani             081                   81
#
#      prov_acr                      reg_name reg_istat_code  \
# 0          TO                      Piemonte             01
# 1          TO                      Piemonte             01
# 2          TO                      Piemonte             01
# 3          TO                      Piemonte             01
# 4          TO                      Piemonte             01
# ...       ...                           ...            ...
# 7894       LE                        Puglia             16
# 7895       TN  Trentino-Alto Adige/Südtirol             04
# 7896       TN  Trentino-Alto Adige/Südtirol             04
# 7897       TN  Trentino-Alto Adige/Südtirol             04
# 7898       TP                       Sicilia             19
#
#       reg_istat_code_num opdm_id com_catasto_code com_istat_code  \
# 0                      1       1             A074         001001
# 1                      1       2             A109         001002
# 2                      1       3             A117         001003
# 3                      1       4             A157         001004
# 4                      1       6             A218         001006
# ...                  ...     ...              ...            ...
# 7894                  16    8366             M428         075098
# 7895                   4    8367             M429         022252
# 7896                   4    8368             M430         022253
# 7897                   4    8369             M431         022254
# 7898                  19    9098             N.d.         081025
#
#       com_istat_code_num                                           geometry
# 0                   1001  MULTIPOLYGON (((7.78266 45.38717, 7.79106 45.3...
# 1                   1002  MULTIPOLYGON (((7.48795 44.93917, 7.49307 44.9...
# 2                   1003  MULTIPOLYGON (((7.27324 45.33927, 7.27360 45.3...
# 3                   1004  MULTIPOLYGON (((7.92507 45.44821, 7.92682 45.4...
# 4                   1006  MULTIPOLYGON (((7.43490 45.13442, 7.43524 45.1...
# ...                  ...                                                ...
# 7894               75098  MULTIPOLYGON (((18.26817 39.93148, 18.27101 39...
# 7895               22252  MULTIPOLYGON (((11.21582 46.44893, 11.21697 46...
# 7896               22253  MULTIPOLYGON (((11.06230 46.49919, 11.06404 46...
# 7897               22254  MULTIPOLYGON (((11.49684 46.36064, 11.49898 46...
# 7898               81025  MULTIPOLYGON (((12.53032 37.97056, 12.53845 37...
#
# [7899 rows x 19 columns]

# %%
# lista univoca dei comuni in ER con codice ISTAT
comuni_er_istat = gdf[gdf["reg_name"]=="Emilia-Romagna"]['com_istat_code'].unique().tolist()
len(comuni_er_istat)
# Out:
# 330

# %%
from istatapi import discovery, retrieval
## RICERCA DEI DATASET BY ID NUMBER:
## 22_289 --> Resident population on 1st January
ds = discovery.DataSet(dataflow_identifier="22_289")
# VARIABILI DEL DATASET
ds.dimensions_info()

import pandas as pd
from tqdm import tqdm

freq = "A"  # ANNUAL frequency
TIPO_INDDEM = ["JAN"]
ISTATCOMUNE = comuni_er_istat
ETA = 'TOTAL'
SESSO = ["1", "2"]  # MASCHIO FEMMINA
STACIVX = "99"  # TOTAL NO DIVIDED BY MARRIAGE

# Create an empty list to store the results
appended_data = []

# Use tqdm to add a progress bar
for it in tqdm(ISTATCOMUNE, desc="Processing ISTATCOMUNE"):
    ds.set_filters(freq=freq, tipo_dato=TIPO_INDDEM, ITTER107=[it], ETA=ETA, SESSO=SESSO, STACIVX=STACIVX,)
    temp_df = retrieval.get_data(ds)
    appended_data.append(temp_df)

df_er = pd.concat(appended_data, ignore_index=True)
df_er
# Out:
# Processing ISTATCOMUNE: 100%|██████████| 330/330 [21:37<00:00,  3.93s/it]
#              DATAFLOW FREQ    ETA  ITTER107  SESSO  STACIVX TIPO_INDDEM  \
# 0     IT1:22_289(1.5)    A  TOTAL   33001.0    1.0     99.0         JAN
# 1     IT1:22_289(1.5)    A  TOTAL   33001.0    2.0     99.0         JAN
# 2     IT1:22_289(1.5)    A  TOTAL   33001.0    1.0     99.0         JAN
# 3     IT1:22_289(1.5)    A  TOTAL   33001.0    2.0     99.0         JAN
# 4     IT1:22_289(1.5)    A  TOTAL   33001.0    1.0     99.0         JAN
# ...               ...  ...    ...       ...    ...      ...         ...
# 3269  IT1:22_289(1.5)    A  TOTAL   38030.0    2.0     99.0         JAN
# 3270  IT1:22_289(1.5)    A  TOTAL   38030.0    1.0     99.0         JAN
# 3271  IT1:22_289(1.5)    A  TOTAL   38030.0    2.0     99.0         JAN
# 3272  IT1:22_289(1.5)    A  TOTAL   38030.0    1.0     99.0         JAN
# 3273  IT1:22_289(1.5)    A  TOTAL   38030.0    2.0     99.0         JAN
#
#      TIME_PERIOD  OBS_VALUE  BREAK  CONF_STATUS  OBS_PRE_BREAK OBS_STATUS  \
# 0     2019-01-01      976.0    NaN          NaN            NaN        NaN
# 1     2019-01-01     1043.0    NaN          NaN            NaN        NaN
# 2     2020-01-01      974.0    NaN          NaN            NaN        NaN
# 3     2020-01-01     1025.0    NaN          NaN            NaN        NaN
# 4     2021-01-01      959.0    NaN          NaN            NaN        NaN
# ...          ...        ...    ...          ...            ...        ...
# 3269  2021-01-01     3570.0    NaN          NaN            NaN        NaN
# 3270  2022-01-01     3333.0    NaN          NaN            NaN        NaN
# 3271  2022-01-01     3618.0    NaN          NaN            NaN        NaN
# 3272  2023-01-01     3335.0    NaN          NaN            NaN          e
# 3273  2023-01-01     3612.0    NaN          NaN            NaN          e
#
#       BASE_PER  UNIT_MEAS  UNIT_MULT  METADATA_EN  METADATA_IT  \
# 0          NaN        NaN        NaN          NaN          NaN
# 1          NaN        NaN        NaN          NaN          NaN
# 2          NaN        NaN        NaN          NaN          NaN
# 3          NaN        NaN        NaN          NaN          NaN
# 4          NaN        NaN        NaN          NaN          NaN
# ...        ...        ...        ...          ...          ...
# 3269       NaN        NaN        NaN          NaN          NaN
# 3270       NaN        NaN        NaN          NaN          NaN
# 3271       NaN        NaN        NaN          NaN          NaN
# 3272       NaN        NaN        NaN          NaN          NaN
# 3273       NaN        NaN        NaN          NaN          NaN
#
#      Not Found - NoRecordsFound
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...
# 3269                        NaN
# 3270                        NaN
# 3271                        NaN
# 3272                        NaN
# 3273                        NaN
#
# [3274 rows x 19 columns]

# %%
TIME_PERIOD = "2023-01-01"

df_er = df_er[df_er['TIME_PERIOD'] >= TIME_PERIOD]
df_er = df_er[['DATAFLOW', 'FREQ', 'ETA', 'ITTER107', 'SESSO', 'STACIVX','TIPO_INDDEM', 'TIME_PERIOD', 'OBS_VALUE']]
df_er['SESSO'] = df_er['SESSO'].map({1: 'maschi', 2: 'femmine'})
df_er['OBS_VALUE'] = df_er['OBS_VALUE'].astype(int)
df_er['ITTER107'] = df_er['ITTER107'].astype(int)
df_er['ITTER107'] = df_er['ITTER107'].astype(str).apply(lambda x: str(x).zfill(6))
df_er
# Out:
#              DATAFLOW FREQ    ETA ITTER107    SESSO  STACIVX TIPO_INDDEM  \
# 8     IT1:22_289(1.5)    A  TOTAL   033001   maschi     99.0         JAN
# 9     IT1:22_289(1.5)    A  TOTAL   033001  femmine     99.0         JAN
# 18    IT1:22_289(1.5)    A  TOTAL   033002   maschi     99.0         JAN
# 19    IT1:22_289(1.5)    A  TOTAL   033002  femmine     99.0         JAN
# 28    IT1:22_289(1.5)    A  TOTAL   033003   maschi     99.0         JAN
# ...               ...  ...    ...      ...      ...      ...         ...
# 3257  IT1:22_289(1.5)    A  TOTAL   034051  femmine     99.0         JAN
# 3264  IT1:22_289(1.5)    A  TOTAL   038029   maschi     99.0         JAN
# 3265  IT1:22_289(1.5)    A  TOTAL   038029  femmine     99.0         JAN
# 3272  IT1:22_289(1.5)    A  TOTAL   038030   maschi     99.0         JAN
# 3273  IT1:22_289(1.5)    A  TOTAL   038030  femmine     99.0         JAN
#
#      TIME_PERIOD  OBS_VALUE
# 8     2023-01-01        971
# 9     2023-01-01       1008
# 18    2023-01-01       2311
# 19    2023-01-01       2373
# 28    2023-01-01        463
# ...          ...        ...
# 3257  2023-01-01       6448
# 3264  2023-01-01       3626
# 3265  2023-01-01       3762
# 3272  2023-01-01       3335
# 3273  2023-01-01       3612
#
# [656 rows x 9 columns]

# %%
df_er.to_excel('popolazione.xlsx',index=False)
df_er.to_parquet('popolazione.parquet',index=False)

# %% [markdown]
# ## IMPORT vs EXPORT exmple

# %%
# initialize the dataset and get its dimensions
ds = discovery.DataSet(dataflow_identifier="139_176")

# %%
ds.dimensions_info()
# Out:
#           dimension         dimension_ID          description
# 0              FREQ              CL_FREQ            Frequency
# 1  MERCE_ATECO_2007  CL_ATECO_2007_MERCE  Commodity Nace 2007
# 2     PAESE_PARTNER               CL_ISO          Geopolitics
# 3          ITTER107          CL_ITTER107            Territory
# 4         TIPO_DATO       CL_TIPO_DATO12         Data type 12

# %%
dimension = "TIPO_DATO" #use "dimension" column from above
ds.get_dimension_values(dimension)
# Out:
#   values_ids                                 values_description
# 0         EV                              export - value (euro)
# 1        TBV                       trade balance - value (euro)
# 2       ISAV  import - seasonally adjusted value - world bas...
# 3       ESAV  export - seasonally adjusted value - world bas...
# 4      TBSAV  trade balance - seasonally adjusted value  -wo...
# 5         IV                              import - value (euro)

# %%
freq = "M" #monthly frequency
tipo_dato = ["ISAV", "ESAV"] #imports and exports seasonally adjusted data
paese_partner = "WORLD" #trade with all countries

ds.set_filters(freq = freq, tipo_dato = tipo_dato, paese_partner = paese_partner)

# %%
trade_df = retrieval.get_data(ds)
trade_df
# Out:
#              DATAFLOW FREQ  MERCE_ATECO_2007 PAESE_PARTNER ITTER107 TIPO_DATO  \
# 0    IT1:139_176(1.0)    M                10         WORLD    ITTOT      ESAV
# 369  IT1:139_176(1.0)    M                10         WORLD    ITTOT      ISAV
# 373  IT1:139_176(1.0)    M                10         WORLD    ITTOT      ISAV
# 4    IT1:139_176(1.0)    M                10         WORLD    ITTOT      ESAV
# 374  IT1:139_176(1.0)    M                10         WORLD    ITTOT      ISAV
#
#     TIME_PERIOD  OBS_VALUE  BREAK  CONF_STATUS  OBS_PRE_BREAK  OBS_STATUS  \
# 0    1993-01-01      10763    NaN          NaN            NaN         NaN
# 369  1993-01-01       9211    NaN          NaN            NaN         NaN
# 373  1993-02-01      10017    NaN          NaN            NaN         NaN
# 4    1993-02-01      10684    NaN          NaN            NaN         NaN
# 374  1993-03-01       9957    NaN          NaN            NaN         NaN
#
#      BASE_PER  UNIT_MEAS  UNIT_MULT  METADATA_EN  METADATA_IT
# 0         NaN        NaN        NaN          NaN          NaN
# 369       NaN        NaN        NaN          NaN          NaN
# 373       NaN        NaN        NaN          NaN          NaN
# 4         NaN        NaN        NaN          NaN          NaN
# 374       NaN        NaN        NaN          NaN          NaN

# %%
# set matplotlib themes
plt.rcParams['figure.figsize'] = [16, 5]

#COLOR palette
colors = ['#30a2da', '#fc4f30', '#e5ae38', '#6d904f', '#8b8b8b']

# calculate moving averages for the plot
trade_df["MA_3"] = trade_df.groupby("TIPO_DATO")["OBS_VALUE"].transform(lambda x: x.rolling(window=3).mean())

#replace the "TIPO_DATO" column values with more meaningful labels
trade_df["TIPO_DATO"] = trade_df["TIPO_DATO"].replace({"ISAV": "Imports", "ESAV": "Exports"})

# Plot the data
after_2013 = trade_df["TIME_PERIOD"] >= "2013"
is_ESAV = trade_df["TIPO_DATO"] == "Exports"
is_ISAV = trade_df["TIPO_DATO"] == "Imports"

exports = trade_df[is_ESAV & after_2013].rename(columns={"OBS_VALUE": "Exports", "MA_3": "Exports - three months moving average"})
imports = trade_df[is_ISAV & after_2013].rename(columns={"OBS_VALUE": "Imports", "MA_3": "Imports - three months moving average"})

plt.plot(
    "TIME_PERIOD",
    "Exports",
    data=exports,
    marker="",
    linestyle="dashed",
    color = colors[0],
    linewidth=1
)
plt.plot(
    "TIME_PERIOD",
    "Imports",
    data=imports,
    marker="",
    linestyle="dashed",
    color = colors[1],
    linewidth=1
)
plt.plot(
    "TIME_PERIOD",
    "Exports - three months moving average",
    data=exports,
    color = colors[0],
    linewidth=2
)
plt.plot(
    "TIME_PERIOD",
    "Imports - three months moving average",
    data=imports,
    marker="",
    color = colors[1],
    linewidth=2
)

# add a title
plt.title("Italy's trade with the world")

# add a label to the x axis
plt.xlabel("Year")

# turn y scale from millions to billions (divide by a 1000), and add a label
plt.ylabel("Value in billions of euros")
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x/1000))))
plt.legend()
